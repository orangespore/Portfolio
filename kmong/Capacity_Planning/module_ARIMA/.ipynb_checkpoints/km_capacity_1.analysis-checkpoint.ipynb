# %%
1. 정상성 확인
- adf 검정
-> d의 값을 찾는다.

2. 계절성 확인
-> 계절정시 존재하면 sarima 아니면 arima

acf, pacf로 ar과 ma의 파라미터를 결정해야 하지만 aic 기준으로 최적의 조합을 결정하여 모델링

# %%
# 분석할 데이터 불러오기

# 필수 파라미터 설정
import pandas as pd
import numpy as np
path = '/home/heemok/km/km_capacity_prediction/'
# 분석 데이터 선택
path_data = path+'Raw_Data.xlsx'

# %% [markdown]
# ## 데이터 불러오기 및 전처리

# %%
def load_data(path):
    df = pd.read_excel(path)
    df['Date']= pd.to_datetime(df['Date'], format='%Y%m%d')
    df_ts = pd.Series(df['N_Order'])
    df_ts.index = df['Date'].values
    df_ts = df_ts[:].astype(np.float)
    return df

df = load_data(path_data)

# %%
df

# %% [markdown]
# ## 데이터 분리

# %%
train_size = int(len(df_ts)*.7)
valid_size = int(len(df_ts)*.1)

features_train = df_ts.iloc[0:train_size]
features_valid = df_ts.iloc[train_size+1:train_size+valid_size]
features_test = df_ts.iloc[train_size+valid_size+1:]

# %% [markdown]
# ## 가설 검정
#     * 사용자 임의 선택을 위한 함수
#     - p와 q : acf/pacf
#     - d : adf 검정을 통한 최소의 d 찾기
#     - 계절성 확인 : 모델 선택 여부

# %%
df_ts.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
# Draw Plot
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(df_ts, ax=ax1, lags=50)
plot_pacf(df_ts, ax=ax2, lags=20)

# Decorate
# lighten the borders
ax1.spines["top"].set_alpha(.3); ax2.spines["top"].set_alpha(.3)
ax1.spines["bottom"].set_alpha(.3); ax2.spines["bottom"].set_alpha(.3)
ax1.spines["right"].set_alpha(.3); ax2.spines["right"].set_alpha(.3)
ax1.spines["left"].set_alpha(.3); ax2.spines["left"].set_alpha(.3)

# font size of tick labels
ax1.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
plt.show()

# %%
#Perform Dickey-Fuller test:
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries, plot=False):
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value',
    '#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    if plot:
        print (dfoutput)
    else:
        return dfoutput
        
#%%
      
#test_stationarity(features_train)
'''
print 'Dickey-Fuller test for original data'
test_stationarity(features_train, plot=True)
'''
p_value = test_stationarity(features_train).iloc[1]

#%% 
#Log Transformation
features_train_log = np.log(features_train)
p_value_log = test_stationarity(features_train_log).iloc[1]
#%%
#First Differencing
features_train_diff = features_train - features_train.shift(1)
features_train_diff.dropna(inplace=True)
p_value_diff = test_stationarity(features_train_diff).iloc[1]
#%%
#Second Differencing
features_train_diff2 = features_train_diff - features_train_diff.shift(1)
features_train_diff2.dropna(inplace=True)
p_value_diff2 = test_stationarity(features_train_diff2).iloc[1]
#%%
#Differencing + log
train_log_diff = features_train_log - features_train_log.shift(1)
train_log_diff.dropna(inplace=True)
p_value_log_diff = test_stationarity(train_log_diff).iloc[1]
#%%
#Second Difference + Log
train_log_diff2 = train_log_diff - train_log_diff.shift(1)
train_log_diff2.dropna(inplace=True)
p_value_log_diff2 = test_stationarity(train_log_diff2).iloc[1]
#%%
#find best transformation
p_value_list = [p_value, p_value_log, p_value_diff, 
                p_value_log_diff, p_value_diff2, p_value_log_diff2]

winner_index = p_value_list.index(min(p_value_list))

# %%
p_value_list
# Out:
# [0.01536642931793242,
#  0.3855543412002951,
#  1.1561231932400557e-14,
#  9.882200622325389e-17,
#  1.31002812379735e-19,
#  1.1144634712609486e-19]

# %%
winner_index
# Out:
# 5

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import acf

#import properties as pr
#from Forecasting import Sarima_forecast, Var_forecast

def Seasonality(DataSet): 
    uniData =  DataSet        # Univariate Data
    lag_acf = acf(uniData.diff().dropna(), nlags=50)
    acf1 = []
    acf2 = []
    for i in range(1,5):
        if i%2 == 0:
            acf2.append(lag_acf[i*12])
        else:
            acf1.append(lag_acf[i*12])
    # Check for seasonality with the (12,36) lag and (24,48) lag  
    if (abs(acf1[0]-acf1[1]) < 0.1) and (abs(acf2[0]-acf2[1])<0.1):
        print("Data is seasonal") 
        #Sarima_forecast.SARIMA_forecasting(Data = uniData,Time_Column = timecolumn,Target_Column = target)
    else:
        print("Data is Not Seasonal")
        #Var_forecast.VAR_forecasting(Data=Data, Time_Column= timecolumn,Target_Column=target)

def Read_Dataset(dataset,timecolumn,target):
    """ Read and Modify The DataSet
    dataset variable holds the location and name of the Dataset
    timecolumn holds the TIME column"""

    series = pd.read_csv(dataset)
    series[timecolumn] = pd.to_datetime(series[timecolumn])
    series[pr.column_date] = [d.date() for d in series[timecolumn]]
    series[pr.column_date] = pd.to_datetime(series[pr.column_date])
    data = series.drop(timecolumn, axis=1)
    data = data.drop(pr.column_date,axis =1)
    data = data.set_index(series[pr.column_date])
    #data = data.loc['2010-01-01 00:00:00+00:00':'2011-01-01 00:00:00+00:00']
    weekly = data.resample('D').mean()
Seasonality(DataSet=features_test)
# Out:
# Data is seasonal
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning

# %%
pip install Forecasting
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: http://dev.tand.kr:9999/repository/pypi/simple
# ERROR: Could not find a version that satisfies the requirement Forecasting
# ERROR: No matching distribution found for Forecasting
# WARNING: You are using pip version 20.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 모델링
#     - 모델 선택
#     - 성능 지표 결과
#     - 시각화

# %%
import warnings
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
    # prepare training dataset

    train_size = int(len(X) * 0.66)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    error = mean_squared_error(test, predictions)
    x_grid = list(range(len(test)))
    
    plt.figure(figsize=(20,10))
    plt.plot(x_grid, test, color='blue')
    plt.plot(x_grid, predictions, color='red')
    plt.legend(['true','pred'])
    plt.show()
    return error

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s MSE=%.3f' % (order,mse))
                except:
                    continue
    print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# load dataset
#series = pd.read_csv('daily-total-female-births.csv', header=0)['Births']

# evaluate parameters
p_values = [0, 1, 2, 4]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(features_test, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=3533817742707.595
# ARIMA(0, 0, 1) MSE=2281334666035.401
# ARIMA(0, 0, 2) MSE=2013308700386.981
# ARIMA(0, 1, 0) MSE=1706084184722.227
# ARIMA(0, 1, 1) MSE=1493125607937.432
# ARIMA(0, 1, 2) MSE=1505512394169.462
# ARIMA(0, 2, 0) MSE=4084782677696.772
# ARIMA(0, 2, 1) MSE=1773468281942.299
# ARIMA(0, 2, 2) MSE=1598943877463.925
# ARIMA(1, 0, 0) MSE=1525884096373.740
# ARIMA(1, 0, 1) MSE=1429304098789.851
# ARIMA(1, 0, 2) MSE=1616874914250.665
# ARIMA(1, 1, 0) MSE=1551957859533.420
# ARIMA(1, 1, 1) MSE=1611362094887.952
# ARIMA(1, 2, 0) MSE=2769120144864.603
# ARIMA(2, 0, 0) MSE=1441054684296.491
# ARIMA(2, 0, 1) MSE=1466061230214.932
# ARIMA(2, 1, 0) MSE=1576298450142.533
# ARIMA(2, 2, 0) MSE=2471342959343.113
# ARIMA(2, 2, 1) MSE=1732774521925.855
# ARIMA(4, 0, 0) MSE=1491543932897.339
# ARIMA(4, 0, 1) MSE=1523435072992.690
# ARIMA(4, 0, 2) MSE=1416993286179.878
# ARIMA(4, 1, 0) MSE=1548853159845.798
# ARIMA(4, 1, 1) MSE=1577628497866.942
# ...

# %%
https://github.com/ChristopherSP/Auto_SARIMAX/blob/master/auto_sarimax.ipynb

# %%
len(features_test)
# Out:
# 100

# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import math
from statsmodels.tsa.seasonal import seasonal_decompose

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(features_valid,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])

results.plot_diagnostics(figsize=(15, 12))
plt.show()
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1630.6433970181834
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:649719484.2779166
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1143.6727719631315
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:741.7768231027413
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1174.953729240562
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:603764776.4969122
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:774.026709316551
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:743.7208038283441
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1569.885379088496
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:617410986.9284028
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1106.7468929317665
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:709.7051719565657
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1220.7751337590626
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:571456330.7998382
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:775.4020068251943
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:711.6987299746567
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1473.5721209079989
# ...

# %%
# Get forecast 500 steps ahead in future
pred_uc = results.get_forecast(steps=100)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

ax = features_test.plot(label='observed', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Passengers Count')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e01c4961d3eb> in <module>
#       6
#       7 ax = features_test.plot(label='observed', figsize=(20, 15))
# ----> 8 pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
#       9 ax.fill_between(pred_ci.index,
#      10                 pred_ci.iloc[:, 0],
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
# ...

# %%
features_test
# Out:
# 2015-10-15    7124688.0
# 2015-10-16    5473922.0
# 2015-10-19    6432366.0
# 2015-10-20    4911618.0
# 2015-10-21    6431239.0
#                 ...
# 2016-03-07    4033182.0
# 2016-03-08    6536110.0
# 2016-03-09    5799946.0
# 2016-03-10    7983483.0
# 2016-03-11    4710626.0
# Name: N_Order, Length: 100, dtype: float64

# %%
valid_test

# %%
plt.show()

# %%
from sklearn.metrics import mean_squared_error
tr_start, tr_end = '2003-01', '2015-10-14' # train & test size 고민해볼 것
te_start, te_end = '2017-07', '2016-03-11'

pred = results.predict(start=pd.to_datetime(tr_end),end=pd.to_datetime(te_end))[1:]
pred.index = features_test.index
print('ARIMA model MSE:{}'.format(mean_squared_error(features_test,pred)))

pd.DataFrame({'test':features_test,'pred':pred}).plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1444780800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
results.forcast(steps=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-2ab97f4a86ef> in <module>
# ----> 1 results.forcast(steps=10)
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      34             pass
#      35
# ---> 36         obj = getattr(results, attr)
#      37         data = results.model.data
#      38         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'SARIMAXResults' object has no attribute 'forcast'

# %%
y = pd.read_csv('air.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)

# %%
features_valid.index
# Out:
# DatetimeIndex(['2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06',
#                '2015-08-07', '2015-08-10', '2015-08-11', '2015-08-12',
#                '2015-08-13', '2015-08-17', '2015-08-18', '2015-08-19',
#                '2015-08-20', '2015-08-21', '2015-08-24', '2015-08-25',
#                '2015-08-26', '2015-08-27', '2015-08-28', '2015-08-31',
#                '2015-09-01', '2015-09-02', '2015-09-03', '2015-09-04',
#                '2015-09-07', '2015-09-08', '2015-09-09', '2015-09-10',
#                '2015-09-11', '2015-09-14', '2015-09-15', '2015-09-16',
#                '2015-09-17', '2015-09-18', '2015-09-21', '2015-09-22',
#                '2015-09-23', '2015-09-24', '2015-09-25', '2015-09-30',
#                '2015-10-01', '2015-10-02', '2015-10-05', '2015-10-06',
#                '2015-10-07', '2015-10-08', '2015-10-12', '2015-10-13'],
#               dtype='datetime64[ns]', freq=None)

# %%
y
# Out:
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: values, Length: 144, dtype: int64

# %%
data = (features_valid/10000).round(1)

# %%
mod = sm.tsa.statespace.SARIMAX(data,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

# %%
results.predict(tr_end,te_end)[1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# ...

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2015-10-01'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

ax = data['2015':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2015-10-01'), data.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Passengers Count')

plt.legend()
plt.show()

# %%
# Get forecast 500 steps ahead in future
pred_uc = results.get_forecast(steps=30)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

#ax = data.plot(x='datetime', label='observed', figsize=(20, 15))
te = (features_test.head(30)/10000).round(1)
plt.plot(list(range(start=50, 30)), te.values)
pred_uc.predicted_mean.plot(x='datetime', label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Passengers Count')

plt.legend()
plt.show()
# Out:
#   File "<ipython-input-89-2236b1e3f965>", line 9
#     plt.plot(list(range(start=50, 30)), te.values)
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
data
# Out:
# 2015-08-03     546.6
# 2015-08-04     568.4
# 2015-08-05     629.5
# 2015-08-06     634.0
# 2015-08-07     546.1
# 2015-08-10     595.2
# 2015-08-11     892.2
# 2015-08-12    1048.1
# 2015-08-13    1090.8
# 2015-08-17     562.0
# 2015-08-18     565.8
# 2015-08-19     737.3
# 2015-08-20     677.9
# 2015-08-21     790.6
# 2015-08-24    1097.5
# 2015-08-25    1206.4
# 2015-08-26    1132.6
# 2015-08-27     886.8
# 2015-08-28     683.6
# 2015-08-31     684.7
# 2015-09-01     767.0
# 2015-09-02     929.5
# 2015-09-03     661.9
# 2015-09-04     896.0
# 2015-09-07     844.4
# 2015-09-08     842.7
# 2015-09-09     994.6
# 2015-09-10    1431.8
# 2015-09-11     644.1
# 2015-09-14     674.2
# 2015-09-15     538.6
# 2015-09-16     767.7
# 2015-09-17     642.7
# 2015-09-18     922.3
# 2015-09-21     667.5
# 2015-09-22     618.9
# 2015-09-23     679.2
# 2015-09-24     570.8
# 2015-09-25     711.5
# 2015-09-30     737.8
# 2015-10-01     801.3
# 2015-10-02     736.7
# 2015-10-05     856.2
# ...
