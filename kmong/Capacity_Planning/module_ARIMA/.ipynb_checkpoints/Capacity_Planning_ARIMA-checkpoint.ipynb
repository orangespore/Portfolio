# %%
import warnings
import main_arima
from main_arima import main
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 조건 설정

# %%
# 파라미터 튜닝 범위 설정
p = d = q = range(0, 2)

# Raw_Data.xlsx를 두고 있는 폴더의 경로
path = 'C:/Users/KRX/Projects/Capacity_Planning/Data/'
# 분석 데이터 선택
path_data = path+'Raw_Data.xlsx'

# %% [markdown]
# ### 분석 실행

# %%
config = {
            "path" : path,
            "path_data" : path_data,
            "p" : p,
            "d" : d,
            "q" : q
         }

result, result_valid = main(config)
# Out:
# =========================================================================================================================
# 1) acf/pacf 시각화
# =========================================================================================================================
# =========================================================================================================================
# 2) 정상성
# =========================================================================================================================
# < 원본 결과 >
# < Dickey-Fuller Test 결과 >
# Test Statistic                   -2.260028
# p-value                           0.185184
# #Lags Used                       13.000000
# Number of Observations Used    1243.000000
# Critical Value (1%)              -3.435622
# Critical Value (5%)              -2.863868
# Critical Value (10%)             -2.568009
# dtype: float64
# < 1차 차분 결과 >
# < Dickey-Fuller Test 결과 >
# Test Statistic                -1.434005e+01
# p-value                        1.063823e-26
# #Lags Used                     1.100000e+01
# Number of Observations Used    1.244000e+03
# Critical Value (1%)           -3.435618e+00
# Critical Value (5%)           -2.863866e+00
# Critical Value (10%)          -2.568008e+00
# dtype: float64
# < 2차 차분 결과 >
# < Dickey-Fuller Test 결과 >
# Test Statistic                -1.435786e+01
# p-value                        9.963461e-27
# #Lags Used                     2.300000e+01
# Number of Observations Used    1.231000e+03
# Critical Value (1%)           -3.435673e+00
# Critical Value (5%)           -2.863891e+00
# Critical Value (10%)          -2.568022e+00
# dtype: float64
# 정상성 만족 차분 :  2
# =========================================================================================================================
# 3) 계절성
# =========================================================================================================================
# 이 데이터는 계절성이 보이므로 SARIMA 적용
# =========================================================================================================================
# 4) 파라미터 튜닝 결과
# =========================================================================================================================
# Best (p,d,q) :  (1, 0, 1)
# Best Seasonal (p,d,q) :  (0, 1, 1, 12)
# =========================================================================================================================
# 5) 성능 평가
# =========================================================================================================================
# result - test data
# Model               : SARIMA
# R2                  : -0.5619
# MAE                 : 8272570.50
# MSE                 : 144542176912367.38
# RMSE                : 12022569.48
# MAPE                : 29.13
# MPE                 : 21.08
# result - validation data
# Model               : SARIMA
# R2                  : -0.5246
# MAE                 : 3992796.54
# MSE                 : 33328478693107.00
# RMSE                : 5773082.25
# MAPE                : 19.28
# MPE                 : 13.48
# =========================================================================================================================
# 6) 예측값 - 실제값 비교
# =========================================================================================================================
# result - test data
# =========================================================================================================================
# 최대 일별 낭비 용량(만건) :  1712
# =========================================================================================================================
#
#  result - validation data
# =========================================================================================================================
# 최대 일별 낭비 용량(만건) :  2362
# =========================================================================================================================
