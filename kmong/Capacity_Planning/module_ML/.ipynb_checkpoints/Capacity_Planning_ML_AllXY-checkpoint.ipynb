# %%
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from main_ml import main
from viz_ml import *

# %% [markdown]
# ### 조건 설정

# %%
# Raw_Data.xlsx를 두고 있는 폴더의 경로
path = 'C:/Users/KRX/Projects/Capacity_Planning/Data/'
# 분석 데이터 선택
path_data = path+'Raw_Data.xlsx'
# 상관관계 데이터 저장 경로
path_data_corr = path+'Raw_Data_corr.xlsx'

# 도메인지식을 활용하여 선택한 최종 변수
lst_sel_features = ["N_Order", "N_Trade", "P_Trading_Volume_F", 
                    "N_Investor", "N_Traded_Symbol_O", "P_Margin","P_K200S","P_VKOSPI"]
# 주요 변수 선택(all 모델에서는 불필요)
Stat_Features = ["N_Order_T1","P_VKOSPI_T1","Max_Capacity"]

# 모델 종류 - 현재 해당 분석에서 모델들은 모두 사용하게 설정
# 따라서, 파라미터의 범위만 변경 가능
model_rf = RandomForestRegressor()
model_dt = DecisionTreeRegressor()
model_lasso = Lasso()
model_ridge = Ridge()
model_xgb = XGBRegressor()

# 모델별 튜닝할 파라미터 선택
lst_params_rf = {"bootstrap":[False], "n_estimators":[3, 10], "max_features":[4, 8, 12, 16, 20]}
lst_params_dt = {"criterion": ["mse", "mae"], "min_samples_split": [5, 10, 20], "max_depth": [6, 8, 10, 12],
                 "min_samples_leaf": [5, 10, 15, 20], "max_leaf_nodes": [5, 10, 20]}
lst_params_lasso = {"alpha":[0.001, 0.01, 0.1, 1, 10, 100, 1000]}
lst_params_ridge = {"alpha":[0.001, 0.01, 0.1, 1, 10, 100, 1000]}
lst_params_xgb =  {'max_depth':[ 6, 8, 10, 12],'n_estimators':[3, 10, 20],'colsample_bytree':[0.5,0.7,1],
                   'colsample_bylevel':[0.5,0.7,1]}
dict_modelling = {
                        'Randomforest' : [model_rf, lst_params_rf],
                        'Decisiontree' : [model_dt, lst_params_dt],
                        'Lasso' : [model_lasso, lst_params_lasso],
                        'Ridge' : [model_ridge, lst_params_ridge],
                        'Xgboost' : [model_xgb, lst_params_xgb]
                 }

# 생성 X,Y 조합 선택
lst_XY = [(10,20),(20,20),(20,40),(40,40),(60,40),(40,60),(60,60),(120,60),(120,120)]
#lst_XY = [(60,40),(40,60),(60,60)]

# %% [markdown]
# ### 분석 실행

# %%
config = {
            "path" : path,
            "path_data" : path_data,
            "path_data_corr" : path_data_corr,
            "lst_sel_features" : lst_sel_features,
            "Stat_Features" : Stat_Features,
            "dict_modelling" : dict_modelling,
            "lst_XY" : lst_XY   
         }

result, result_valid = main(config, 'all')
# Out:
# ===================================================================================
# (X,Y) (40, 40) 모델 별 결과
# ===================================================================================
# Randomforest 모델
# Test result
# R2                  : 0.9573
# MAE                 : 1683153.68
# MSE                 : 5037392013017.64
# RMSE                : 2244413.51
# MAPE                : 11.12
# MPE                 : -6.11
# Validation result
# R2                  : 0.9738
# MAE                 : 1348329.53
# MSE                 : 3736378743903.59
# RMSE                : 1932971.48
# MAPE                : 8.57
# MPE                 : -3.52
# ===================================================================================
# Decisiontree 모델
# Test result
# R2                  : 0.8665
# MAE                 : 2592328.98
# MSE                 : 15748207551527.14
# RMSE                : 3968401.13
# MAPE                : 15.90
# MPE                 : -6.32
# Validation result
# R2                  : 0.8652
# MAE                 : 2693508.00
# MSE                 : 19242280946379.63
# RMSE                : 4386602.44
# MAPE                : 14.79
# MPE                 : -3.72
# ===================================================================================
# Lasso 모델
# Test result
# R2                  : 0.9397
# MAE                 : 1988656.13
# MSE                 : 7108710247557.97
# RMSE                : 2666216.47
# MAPE                : 11.60
# MPE                 : -3.05
# Validation result
# R2                  : 0.9418
# MAE                 : 2146339.99
# MSE                 : 8306239509573.46
# RMSE                : 2882054.74
# MAPE                : 11.20
# MPE                 : -5.56
# ===================================================================================
# Ridge 모델
# Test result
# R2                  : 0.9263
# MAE                 : 2246925.73
# MSE                 : 8688343477093.41
# RMSE                : 2947599.61
# MAPE                : 14.20
# MPE                 : -9.57
# Validation result
# R2                  : 0.9088
# MAE                 : 2553447.54
# MSE                 : 13016527458299.25
# RMSE                : 3607842.49
# MAPE                : 13.59
# MPE                 : -11.38
# ===================================================================================
# Xgboost 모델
# Test result
# R2                  : 0.9503
# MAE                 : 1844776.15
# MSE                 : 5867738035039.71
# RMSE                : 2422341.44
# MAPE                : 11.96
# MPE                 : -6.66
# Validation result
# R2                  : 0.9638
# MAE                 : 1668529.96
# MSE                 : 5173075458197.01
# RMSE                : 2274439.59
# MAPE                : 10.44
# MPE                 : -6.12
# ===================================================================================
# ===================================================================================
# (X,Y) (60, 40) 모델 별 결과
# ===================================================================================
# Randomforest 모델
# Test result
# R2                  : 0.9681
# MAE                 : 1361299.81
# MSE                 : 3373187352468.77
# RMSE                : 1836623.90
# MAPE                : 9.25
# MPE                 : -4.63
# Validation result
# R2                  : 0.7683
# MAE                 : 3164509.65
# MSE                 : 18532091296976.29
# RMSE                : 4304891.55
# MAPE                : 21.37
# MPE                 : -17.92
# ===================================================================================
# Decisiontree 모델
# Test result
# R2                  : 0.8137
# MAE                 : 2537059.10
# MSE                 : 19689634929384.22
# RMSE                : 4437300.41
# MAPE                : 15.02
# MPE                 : -6.57
# Validation result
# R2                  : 0.0378
# MAE                 : 5054203.39
# MSE                 : 76976790248025.56
# RMSE                : 8773641.79
# MAPE                : 30.36
# MPE                 : -23.91
# ===================================================================================
# Lasso 모델
# Test result
# R2                  : 0.9375
# MAE                 : 1952180.29
# MSE                 : 6603893530460.00
# RMSE                : 2569804.18
# MAPE                : 12.22
# MPE                 : -3.87
# Validation result
# R2                  : 0.7363
# MAE                 : 3647974.92
# MSE                 : 21095372963042.30
# RMSE                : 4592969.95
# MAPE                : 24.68
# MPE                 : -22.70
# ===================================================================================
# Ridge 모델
# Test result
# R2                  : 0.9494
# MAE                 : 1853268.83
# MSE                 : 5343232343655.90
# RMSE                : 2311543.28
# MAPE                : 13.19
# MPE                 : -2.80
# Validation result
# R2                  : 0.9198
# MAE                 : 1972303.73
# MSE                 : 6417947241004.92
# RMSE                : 2533366.78
# MAPE                : 14.48
# MPE                 : -5.22
# ===================================================================================
# Xgboost 모델
# Test result
# R2                  : 0.9570
# MAE                 : 1514819.25
# MSE                 : 4547666101217.17
# RMSE                : 2132525.76
# MAPE                : 11.04
# MPE                 : -6.04
# Validation result
# R2                  : 0.7098
# MAE                 : 3686666.64
# MSE                 : 23218595829333.08
# RMSE                : 4818567.82
# MAPE                : 27.99
# MPE                 : -26.97
# ===================================================================================
# ===================================================================================
# (X,Y) (40, 60) 모델 별 결과
# ===================================================================================
# Randomforest 모델
# Test result
# R2                  : 0.9474
# MAE                 : 1871044.56
# MSE                 : 6805746762311.17
# RMSE                : 2608782.62
# MAPE                : 9.91
# MPE                 : -1.59
# Validation result
# R2                  : 0.9234
# MAE                 : 2239462.53
# MSE                 : 10449780186258.65
# RMSE                : 3232611.98
# MAPE                : 11.46
# MPE                 : -4.68
# ===================================================================================
# Decisiontree 모델
# Test result
# R2                  : 0.8298
# MAE                 : 3041226.19
# MSE                 : 22032826683304.98
# RMSE                : 4693913.79
# MAPE                : 15.74
# MPE                 : -0.62
# Validation result
# R2                  : 0.8110
# MAE                 : 3076609.79
# MSE                 : 25783920505079.27
# RMSE                : 5077786.97
# MAPE                : 16.16
# MPE                 : -2.95
# ===================================================================================
# Lasso 모델
# Test result
# R2                  : 0.9000
# MAE                 : 2576690.43
# MSE                 : 12937922823848.32
# RMSE                : 3596932.42
# MAPE                : 13.32
# MPE                 : -2.52
# Validation result
# R2                  : 0.8795
# MAE                 : 2724147.71
# MSE                 : 16441278571313.86
# RMSE                : 4054784.65
# MAPE                : 13.24
# MPE                 : -7.09
# ===================================================================================
# Ridge 모델
# Test result
# R2                  : 0.9112
# MAE                 : 2413435.36
# MSE                 : 11490926538035.05
# RMSE                : 3389826.92
# MAPE                : 13.21
# MPE                 : -4.48
# Validation result
# R2                  : 0.8506
# MAE                 : 3426510.00
# MSE                 : 20384897634194.61
# RMSE                : 4514963.75
# MAPE                : 17.72
# MPE                 : -12.19
# ===================================================================================
# Xgboost 모델
# Test result
# R2                  : 0.9248
# MAE                 : 1974874.13
# MSE                 : 9730579134504.47
# RMSE                : 3119387.62
# MAPE                : 11.32
# MPE                 : -5.41
# Validation result
# R2                  : 0.9291
# MAE                 : 2021926.22
# MSE                 : 9667577800859.09
# RMSE                : 3109272.87
# MAPE                : 11.31
# MPE                 : -6.21
# ===================================================================================
# ===================================================================================
# (X,Y) (60, 60) 모델 별 결과
# ===================================================================================
# Randomforest 모델
# Test result
# R2                  : 0.9564
# MAE                 : 1669593.17
# MSE                 : 4869386021833.68
# RMSE                : 2206668.53
# MAPE                : 9.71
# MPE                 : -2.29
# Validation result
# R2                  : 0.9650
# MAE                 : 1578614.01
# MSE                 : 4166603671934.37
# RMSE                : 2041226.02
# MAPE                : 10.05
# MPE                 : -5.14
# ===================================================================================
# Decisiontree 모델
# Test result
# R2                  : 0.8862
# MAE                 : 2294592.13
# MSE                 : 12717452746639.81
# RMSE                : 3566153.77
# MAPE                : 12.67
# MPE                 : -3.61
# Validation result
# R2                  : 0.8834
# MAE                 : 2343274.09
# MSE                 : 13883746876642.01
# RMSE                : 3726090.03
# MAPE                : 14.32
# MPE                 : -5.69
# ===================================================================================
# Lasso 모델
# Test result
# R2                  : 0.9367
# MAE                 : 1982873.54
# MSE                 : 7074814037645.30
# RMSE                : 2659852.26
# MAPE                : 10.92
# MPE                 : -1.24
# Validation result
# R2                  : 0.9316
# MAE                 : 2111212.42
# MSE                 : 8141781672910.98
# RMSE                : 2853380.74
# MAPE                : 13.02
# MPE                 : -6.29
# ===================================================================================
# Ridge 모델
# Test result
# R2                  : 0.9501
# MAE                 : 1808243.22
# MSE                 : 5570906789419.13
# RMSE                : 2360276.85
# MAPE                : 11.03
# MPE                 : -2.07
# Validation result
# R2                  : 0.9564
# MAE                 : 1757934.79
# MSE                 : 5193077964874.69
# RMSE                : 2278832.59
# MAPE                : 12.53
# MPE                 : -5.64
# ===================================================================================
# Xgboost 모델
# Test result
# R2                  : 0.9512
# MAE                 : 1653099.98
# MSE                 : 5450538819138.55
# RMSE                : 2334638.91
# MAPE                : 9.59
# MPE                 : -4.18
# Validation result
# R2                  : 0.9499
# MAE                 : 1827211.88
# MSE                 : 5962698853594.49
# RMSE                : 2441863.81
# MAPE                : 11.73
# MPE                 : -6.10
# ===================================================================================

# %% [markdown]
# ## 전체 데이터의 성능 평가

# %% [markdown]
# ### test data 결과

# %%
viz_total_evaluation(result, 'Test')

# %% [markdown]
# ### validation data 결과

# %%
viz_total_evaluation(result_valid, 'Val')
